# %% [markdown]
# ## Certified AI Practitioner Week 02 Call 01 - Train and Evaluate in the Cloud

# %% [markdown]
# ## Learning Objectives

# %% [markdown]
# - Create SageMaker Studio resources programmatically using CloudFormation
# - Upload data and artifacts to S3 for use with SageMaker
# - Use SageMaker to train a scikit-learn model from a training script
# - View and interpret model performance from CloudWatch logs
# - Explain and interpret confusion matrices and feature importance
# - Understand how IAM roles and S3 permissions enable secure ML workflows
# - Automate model training using the SKLearn Estimator API

# %% [markdown]
# ## Why Train in the Cloud?

# %% [markdown]
# Local notebooks are great for prototyping, but they don’t scale well when working with real-world machine learning workflows. As datasets grow and model complexity increases, training on your laptop becomes slow, inconsistent, and hard to reproduce.
#
# By using **Amazon SageMaker**, we get:
#
# - **Scalability** - Choose from dozens of instance types to train faster
# - **Reproducibility** - Jobs are tracked, versioned, and logged
# - **Separation of concerns** - Training logic is decoupled from local development
# - **Artifact storage** - Models are automatically saved to S3 for reuse
# - **Built-in monitoring** - Logs are streamed to CloudWatch for debugging and analysis
#
# In this session, we’ll shift from training locally to launching a fully managed training job in the cloud.

# %% [markdown]
# ## Infrastructure Setup with CloudFormation

# %% [markdown]
# To train models in SageMaker Studio, we first need to provision the necessary infrastructure.
#
# In this step, we’ll use an automated **CloudFormation template** to create:
#
# - A **SageMaker Studio domain** for running cloud-based notebooks
# - An **IAM execution role** with S3 and SageMaker permissions
# - A dedicated **S3 bucket** to store training data and model artifacts
#
# Instead of clicking through the AWS Console, we’ll deploy this setup programmatically using `boto3`. The stack will output everything you need - including the bucket name and role ARN - to use in the next steps of this notebook.

# %%
import boto3
import json

def stack_exists(name):
    try:
        cf.describe_stacks(StackName=name)
        return True
    except cf.exceptions.ClientError as e:
        if "does not exist" in str(e):
            return False
        raise  # re-raise any unexpected error

def deploy_stack(stack_name, template_body, parameters):
    if stack_exists(stack_name):
        print(f"🔄 Updating stack: {stack_name}")
        try:
            response = cf.update_stack(
                StackName=stack_name,
                TemplateBody=template_body,
                Parameters=parameters,
                Capabilities=["CAPABILITY_NAMED_IAM"]
            )
            waiter = cf.get_waiter("stack_update_complete")
        except cf.exceptions.ClientError as e:
            if "No updates are to be performed" in str(e):
                print("✅ No changes detected.")
                return
            else:
                raise
    else:
        print(f"🚀 Creating stack: {stack_name}")
        response = cf.create_stack(
            StackName=stack_name,
            TemplateBody=template_body,
            Parameters=parameters,
            Capabilities=["CAPABILITY_NAMED_IAM"]
        )
        waiter = cf.get_waiter("stack_create_complete")

    print(f"⏳ Waiting for {stack_name} to complete...")
    waiter.wait(StackName=stack_name)
    print("✅ Stack operation completed.")

    # Print outputs
    outputs = cf.describe_stacks(StackName=stack_name)["Stacks"][0]["Outputs"]
    print("🔧 Stack Outputs:")
    print(json.dumps({o["OutputKey"]: o["OutputValue"] for o in outputs}, indent=2))

ec2 = boto3.client("ec2")
cf = boto3.client("cloudformation")

# Get the default VPC ID
vpc_id = ec2.describe_vpcs(Filters=[{"Name": "isDefault", "Values": ["true"]}])["Vpcs"][0]["VpcId"]

# Get a public subnet ID in that VPC
subnets = ec2.describe_subnets(Filters=[{"Name": "vpc-id", "Values": [vpc_id]}])
subnet_id = subnets["Subnets"][0]["SubnetId"]

# Load your template
with open("cf_templates/sagemaker_infra.yaml") as f:
    template_body = f.read()

bucketNameSuffix = "zali"
stack_name = "caip02-cloud-ml-stack"

parameters = [
    {"ParameterKey": "BucketNameSuffix", "ParameterValue": bucketNameSuffix},
    {"ParameterKey": "VpcId", "ParameterValue": vpc_id},
    {"ParameterKey": "SubnetId", "ParameterValue": subnet_id}
]

deploy_stack(stack_name, template_body, parameters)
# Out:
# 🚀 Creating stack: caip02-cloud-ml-stack
# ⏳ Waiting for caip02-cloud-ml-stack to complete...
# ✅ Stack operation completed.
# 🔧 Stack Outputs:
# {
#   "StudioUserName": "caip02-user",
#   "BucketName": "caip02-ml-bucket-zali",
#   "DomainId": "d-hhdh4ny1diie",
#   "RoleArn": "arn:aws:iam::458806987020:role/caip02-execution-role-zali"
# }

# %% [markdown]
# ## Prepare Titanic Data

# %% [markdown]
# In this step, we’ll clean and preprocess the Titanic dataset using the same logic we applied in Week 1. This prepares the data for training in SageMaker.
#
# We will:
#
# - Load both training and test CSVs from Kaggle
# - Combine them into a single DataFrame
# - Select relevant features
# - Drop rows with missing values (for simplicity)
# - Encode categorical columns (`Sex`, `Embarked`) as numeric values
# - Save the cleaned dataset as `cleaned_titanic.csv`

# %%
import pandas as pd

# Load Titanic training and test datasets
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")

# Combine them into one DataFrame
df = pd.concat([df_train, df_test], ignore_index=True)

# Select relevant columns
cols = ["Survived", "Pclass", "Sex", "Age", "SibSp", "Parch", "Fare", "Embarked"]
df = df[cols]

# Drop rows with missing values (simplified approach)
df = df.dropna()

# Encode categorical features
df["Sex"] = df["Sex"].map({"male": 0, "female": 1})
df["Embarked"] = df["Embarked"].map({"S": 0, "C": 1, "Q": 2})

# Final preview
print("\nCleaned preview:")
display(df.head())

# Save cleaned dataset
df.to_csv("cleaned_titanic.csv", index=False)
print("Saved cleaned_titanic.csv")
# Out:
# Cleaned preview:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0       0.0       3    0  22.0      1      0   7.2500         0
# 1       1.0       1    1  38.0      1      0  71.2833         1
# 2       1.0       3    1  26.0      0      0   7.9250         0
# 3       1.0       1    1  35.0      1      0  53.1000         0
# 4       0.0       3    0  35.0      0      0   8.0500         0
# Saved cleaned_titanic.csv

# %% [markdown]
# ## Upload Data to S3

# %% [markdown]
# Now that we’ve prepared the Titanic dataset, we’ll upload it to our dedicated S3 bucket so it can be used by SageMaker for training.
#
# Make sure you’re using the bucket created by your CloudFormation stack. You can retrieve it from the stack outputs or hardcode it here for now.

# %%
import boto3

bucket_name = "caip02-ml-bucket-zali"  # Replace with your actual bucket name if needed
key = "inputs/cleaned_titanic.csv"

s3 = boto3.client("s3")
s3.upload_file("cleaned_titanic.csv", bucket_name, key)

print(f"Uploaded cleaned_titanic.csv to s3://{bucket_name}/{key}")
# Out:
# Uploaded cleaned_titanic.csv to s3://caip02-ml-bucket-zali/inputs/cleaned_titanic.csv

# %% [markdown]
# ## Write the Training Script (train_model.py)

# %% [markdown]
# SageMaker training jobs run inside isolated containers. Instead of writing code cell by cell, we’ll create a standalone script that SageMaker will execute in the cloud.
#
# This script will:
#
# - Load the Titanic dataset from the input channel
# - Train a Decision Tree model
# - Evaluate performance using a confusion matrix and classification report
# - Print feature importances
# - Save the trained model to the `/opt/ml/model/` directory for SageMaker to capture
#
# We’ll save this script locally so we can pass it into a SageMaker training job.

# %%
from IPython.display import Markdown, display

def show_code(filepath):
    with open(filepath, "r") as f:
        code = f.read()
    display(Markdown(f"```python\n{code}\n```"))

# Call this after writing the file
show_code("train_model.py")
# Out:
# ```python
# import pandas as pd
# import joblib
# import os
#
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler
# from sklearn.metrics import classification_report, confusion_matrix
#
# def main():
#     # SageMaker passes input as /opt/ml/input/data/train/
#     input_path = "/opt/ml/input/data/train/cleaned_titanic.csv"
#     df = pd.read_csv(input_path)
#
#     # Split features and target
#     X = df.drop("Survived", axis=1)
#     y = df["Survived"]
#
#     # Train/test split
#     X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)
#
#     # Scale features
#     scaler = StandardScaler()
#     X_train_scaled = scaler.fit_transform(X_train)
#     X_test_scaled = scaler.transform(X_test)
#
#     # Train model
#     clf = DecisionTreeClassifier(max_depth=3, random_state=42)
#     clf.fit(X_train_scaled, y_train)
#
#     # Evaluate
#     y_pred = clf.predict(X_test_scaled)
#
#     print("\n=== Classification Report ===\n")
#     print(classification_report(y_test, y_pred))
#
#     print("\n=== Confusion Matrix ===\n")
#     print(confusion_matrix(y_test, y_pred))
#
#     print("\n=== Feature Importances ===\n")
#     importances = pd.Series(clf.feature_importances_, index=X.columns)
#     print(importances.sort_values(ascending=False))
#
#     # Save model
#     os.makedirs("/opt/ml/model", exist_ok=True)
#     joblib.dump(clf, "/opt/ml/model/model.joblib")
#
# if __name__ == "__main__":
#     main()
#
# ```

# %% [markdown]
# ## Launch a SageMaker Training Job

# %% [markdown]
# Now that our training script is ready and the data is uploaded to S3, we’ll launch a managed training job using SageMaker.
#
# We’ll use the **SKLearn Estimator**, which runs our `train_model.py` script inside a pre-built scikit-learn container. SageMaker will automatically:
#
# - Mount our data from S3 into the container
# - Run the training script
# - Capture logs in CloudWatch
# - Save the trained model artifact to our specified S3 output path
#
# Once the job completes, we’ll review the logs and retrieve the model if needed.
#
# ### Why Use the SKLearn Estimator?
#
# The `SKLearn` Estimator is ideal for training traditional machine learning models (like decision trees) using **scikit-learn**. It lets us:
#
# - Run our local Python script without modification
# - Avoid building Docker containers
# - Focus on modeling, not infrastructure
# - Use pre-configured SageMaker environments that match local development
#
# ---
#
# ### What Are the Alternatives?
#
# SageMaker provides several Estimators for different use cases:
#
# | Estimator | Use Case | Why We’re Not Using It |
# |----------|----------|-------------------------|
# | `SKLearn` | Scikit-learn models | ✅ Perfect for this training job |
# | `XGBoost` | Gradient boosting for tabular data | ❌ Great for next step, but we’re starting simple |
# | `TensorFlow` / `PyTorch` | Deep learning / neural networks | ❌ Overkill for decision trees |
# | `Estimator` (Generic) | Custom Docker containers | ❌ Too complex for this call |
# | `ScriptProcessor` | Preprocessing scripts (no model training) | ❌ We’re training a model, not just processing data |
#
# This flexibility is one of the key strengths of SageMaker — we can start simple, and scale up when needed.

# %%
from sagemaker.sklearn.estimator import SKLearn
import sagemaker
import boto3

# Values from your CloudFormation stack
bucket = "caip02-ml-bucket-zali"
role = "arn:aws:iam::458806987020:role/caip02-execution-role-zali"
region = boto3.Session().region_name

# Input and output locations in S3
input_path = f"s3://{bucket}/inputs/"
output_path = f"s3://{bucket}/models/"

# Set up the SageMaker session
session = sagemaker.Session()

# Create SKLearn estimator
estimator = SKLearn(
    entry_point="train_model.py",
    role=role,
    instance_type="ml.m5.large",
    framework_version="1.0-1",
    sagemaker_session=session,
    output_path=output_path,
    base_job_name="titanic-decision-tree"
)

# Launch the training job
estimator.fit({"train": input_path})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from sagemaker.sklearn.estimator import SKLearn
#       2 import sagemaker
#       3 import boto3
#
# ModuleNotFoundError: No module named 'sagemaker.sklearn'

# %%
# !pip install sagemaker
# Out:
# Requirement already satisfied: sagemaker in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (3.1.1)
# Requirement already satisfied: sagemaker-core<3.0.0,>=2.1.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker) (2.1.1)
# Requirement already satisfied: sagemaker-train<2.0.0,>=1.1.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker) (1.1.1)
# Requirement already satisfied: sagemaker-serve<2.0.0,>=1.1.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker) (1.1.1)
# Requirement already satisfied: sagemaker-mlops<2.0.0,>=1.1.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker) (1.1.1)
# Requirement already satisfied: boto3<2.0.0,>=1.42.2 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (1.42.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (2.12.5)
# Requirement already satisfied: PyYAML<7.0,>=6.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (6.0.3)
# Requirement already satisfied: jsonschema<5.0.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (4.25.1)
# Requirement already satisfied: platformdirs<5.0.0,>=4.0.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (4.5.1)
# Requirement already satisfied: rich<14.0.0,>=13.0.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (13.9.4)
# Requirement already satisfied: mock<5.0,>4.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (4.0.3)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (6.11.0)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (4.15.0)
# Requirement already satisfied: pytz>=2021.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (2025.2)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (2.32.5)
# Requirement already satisfied: attrs>=20.3.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (25.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (25.0)
# Requirement already satisfied: protobuf<5.0,>=3.12 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (4.25.8)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (2.3.3)
# Requirement already satisfied: numpy>=1.9.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (2.3.5)
# Requirement already satisfied: smdebug_rulesconfig>=1.0.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (1.0.1)
# Requirement already satisfied: schema>=0.7.5 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (0.7.8)
# Requirement already satisfied: omegaconf>=2.1.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (2.3.0)
# Requirement already satisfied: torch>=1.9.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (2.9.1)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (1.16.3)
# Requirement already satisfied: cloudpickle>=2.0.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (3.1.2)
# Requirement already satisfied: paramiko>=2.11.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (4.0.0)
# Requirement already satisfied: tblib>=1.7.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-core<3.0.0,>=2.1.1->sagemaker) (3.2.2)
# Requirement already satisfied: botocore<1.43.0,>=1.42.10 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from boto3<2.0.0,>=1.42.2->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (1.42.10)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from boto3<2.0.0,>=1.42.2->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from boto3<2.0.0,>=1.42.2->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from botocore<1.43.0,>=1.42.10->boto3<2.0.0,>=1.42.2->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from botocore<1.43.0,>=1.42.10->boto3<2.0.0,>=1.42.2->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (2.6.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (3.23.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from jsonschema<5.0.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from jsonschema<5.0.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from jsonschema<5.0.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (0.30.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.10->boto3<2.0.0,>=1.42.2->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from requests<3.0.0,>=2.20.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from requests<3.0.0,>=2.20.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from requests<3.0.0,>=2.20.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (2.19.2)
# Requirement already satisfied: deepdiff in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (8.6.1)
# Requirement already satisfied: mlflow in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (3.7.0)
# Requirement already satisfied: sagemaker_schema_inference_artifacts in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (0.0.5)
# Requirement already satisfied: pytest in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (9.0.2)
# Requirement already satisfied: tqdm in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (4.67.1)
# Requirement already satisfied: psutil in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (7.1.3)
# Requirement already satisfied: tritonclient[http] in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (2.63.0)
# Requirement already satisfied: onnx in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (1.20.0)
# Requirement already satisfied: onnxruntime in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (1.23.2)
# Requirement already satisfied: graphene<4,>=3 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-train<2.0.0,>=1.1.1->sagemaker) (3.4.3)
# Requirement already satisfied: jinja2<4.0,>=3.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-train<2.0.0,>=1.1.1->sagemaker) (3.1.6)
# Requirement already satisfied: sagemaker-mlflow<1.0.0,>=0.0.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker-train<2.0.0,>=1.1.1->sagemaker) (0.2.0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from graphene<4,>=3->sagemaker-train<2.0.0,>=1.1.1->sagemaker) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from graphene<4,>=3->sagemaker-train<2.0.0,>=1.1.1->sagemaker) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from jinja2<4.0,>=3.0->sagemaker-train<2.0.0,>=1.1.1->sagemaker) (3.0.3)
# Requirement already satisfied: mlflow-skinny==3.7.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (3.7.0)
# Requirement already satisfied: mlflow-tracing==3.7.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (3.7.0)
# Requirement already satisfied: Flask-CORS<7 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (6.0.2)
# Requirement already satisfied: Flask<4 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (1.17.2)
# Requirement already satisfied: cryptography<47,>=43.0.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (46.0.3)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (7.1.0)
# Requirement already satisfied: huey<3,>=2.5.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (2.5.5)
# Requirement already satisfied: matplotlib<4 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (3.10.8)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (22.0.0)
# Requirement already satisfied: scikit-learn<2 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (1.8.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (2.0.45)
# Requirement already satisfied: waitress<4 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (3.0.2)
# Requirement already satisfied: cachetools<7,>=5.0.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow-skinny==3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (6.2.4)
# Requirement already satisfied: click<9,>=7.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow-skinny==3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (8.3.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow-skinny==3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (0.74.0)
# Requirement already satisfied: fastapi<1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow-skinny==3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (0.124.4)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow-skinny==3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (3.1.45)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow-skinny==3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (1.39.1)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow-skinny==3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (1.27.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow-skinny==3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (1.39.1)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow-skinny==3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (1.2.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow-skinny==3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (0.5.4)
# Requirement already satisfied: uvicorn<1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from mlflow-skinny==3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (0.38.0)
# Requirement already satisfied: Mako in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from alembic!=1.10.0,<2->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (1.3.10)
# Requirement already satisfied: colorama in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from click<9,>=7.0->mlflow-skinny==3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (0.4.6)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from cryptography<47,>=43.0.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (2.45.0)
# Requirement already satisfied: pywin32>=304 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from docker<8,>=4.0.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (311)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from fastapi<1->mlflow-skinny==3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from fastapi<1->mlflow-skinny==3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (0.0.4)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from Flask<4->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from Flask<4->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (2.2.0)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from Flask<4->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (3.1.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (4.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (3.2.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (0.60b1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from pandas>=1.0.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (2025.3)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (0.6.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from scikit-learn<2->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from scikit-learn<2->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (3.6.0)
# Requirement already satisfied: greenlet>=1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (3.3.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (4.12.0)
# Requirement already satisfied: h11>=0.8 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from uvicorn<1->mlflow-skinny==3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (0.16.0)
# Requirement already satisfied: pycparser in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (2.23)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.0.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (0.1.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from omegaconf>=2.1.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (4.9.3)
# Requirement already satisfied: bcrypt>=3.2 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from paramiko>=2.11.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (5.0.0)
# Requirement already satisfied: invoke>=2.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from paramiko>=2.11.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (2.2.1)
# Requirement already satisfied: pynacl>=1.5 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from paramiko>=2.11.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (1.6.1)
# Requirement already satisfied: filelock in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (3.20.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (3.6.1)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (2025.12.0)
# Requirement already satisfied: setuptools in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sympy>=1.13.3->torch>=1.9.0->sagemaker-core<3.0.0,>=2.1.1->sagemaker) (1.3.0)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from deepdiff->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (5.5.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from onnx->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (0.5.4)
# Requirement already satisfied: coloredlogs in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from onnxruntime->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from onnxruntime->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (25.9.23)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from coloredlogs->onnxruntime->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (3.5.4)
# Requirement already satisfied: iniconfig>=1.0.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from pytest->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from pytest->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (1.6.0)
# Requirement already satisfied: json5>=0.9.22 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from sagemaker_schema_inference_artifacts->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (0.12.1)
# Requirement already satisfied: perf-analyzer in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from tritonclient[http]->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (0.1.0)
# Requirement already satisfied: python-rapidjson>=0.9.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from tritonclient[http]->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (1.23)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from tritonclient[http]->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (3.13.2)
# Requirement already satisfied: geventhttpclient>=2.3.3 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from tritonclient[http]->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (2.3.7)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (1.22.0)
# Requirement already satisfied: gevent in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (25.9.1)
# Requirement already satisfied: brotli in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (1.2.0)
# Requirement already satisfied: zope.event in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from gevent->geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (6.1)
# Requirement already satisfied: zope.interface in c:\users\ziggy\dropbox\github\luit-nov-2025-white-ai\.venv\lib\site-packages (from gevent->geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0,>=1.1.1->sagemaker) (8.1.1)
# WARNING: Ignoring invalid distribution ~ip (c:\Users\Ziggy\Dropbox\GitHub\luit-nov-2025-white-ai\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Users\Ziggy\Dropbox\GitHub\luit-nov-2025-white-ai\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Users\Ziggy\Dropbox\GitHub\luit-nov-2025-white-ai\.venv\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Example Output (Sagemaker Jobs Training Screenshot)
#
# <div align="center">
#   <img src="sm_jobs_training.png" alt="Sagemaker Jobs Training Dashboard" style="width:100%;">
# </div>

# %% [markdown]
# ## Review Results in CloudWatch

# %% [markdown]
# After the SageMaker training job completes, the output of our `train_model.py` script is automatically sent to **Amazon CloudWatch Logs**. This includes:
#
# - The full **classification report**
# - The **confusion matrix** showing predicted vs actual survival
# - A list of **feature importances** ranked by influence on model predictions
#
# These logs are essential for debugging and evaluating model performance — especially when training at scale or remotely.
#
# ---
#
# ### How to View the Logs
#
# 1. Go to the [SageMaker Console](https://console.aws.amazon.com/sagemaker/home)
# 2. Click **Training jobs**
# 3. Select your job name (e.g., `titanic-decision-tree-...`)
# 4. Scroll down to **Monitor** and click the **View logs** link
# 5. Inside CloudWatch Logs, review the printed output from your training script
#
# ---
#
# ### Example Output (CloudWatch Screenshot)
#
# <div align="center">
#   <img src="cw_logs.png" alt="CloudWatch output" style="width:80%;">
# </div>
#
# ---
#
# This output confirms that your training script executed properly and gives you quick insights into model quality — without downloading any files.

# %% [markdown]
# ## Local Model Evaluation (For Comparison)

# %% [markdown]
# Before we trained the model in SageMaker, we could have easily done the same thing locally. This helps us validate that our cloud workflow is working correctly by comparing the same model trained and evaluated in a Jupyter cell.
#
# This block repeats the core logic of our `train_model.py` file but runs right here in the notebook.
#
# You should see the same confusion matrix and feature importance values if everything is consistent.

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import seaborn as sns

# Load cleaned Titanic dataset
df = pd.read_csv("cleaned_titanic.csv")

# Features and target
X = df.drop("Survived", axis=1)
y = df["Survived"]

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

# Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train model
clf = DecisionTreeClassifier(max_depth=3, random_state=42)
clf.fit(X_train_scaled, y_train)

# Predict and evaluate
y_pred = clf.predict(X_test_scaled)

print("=== Classification Report ===\n")
print(classification_report(y_test, y_pred))

# Raw and normalized confusion matrices
cm_raw = confusion_matrix(y_test, y_pred)
cm_norm = confusion_matrix(y_test, y_pred, normalize='true')

# Plot both side-by-side
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Raw counts
ConfusionMatrixDisplay(confusion_matrix=cm_raw).plot(ax=axes[0], cmap='Blues', values_format='d')
axes[0].set_title("Confusion Matrix (Raw Counts)")

# Normalized
ConfusionMatrixDisplay(confusion_matrix=cm_norm).plot(ax=axes[1], cmap='Purples', values_format=".2f")
axes[1].set_title("Confusion Matrix (Normalized by Row)")

plt.tight_layout()
plt.show()

# Feature importance plot
importances = pd.Series(clf.feature_importances_, index=X.columns).sort_values()
plt.figure(figsize=(8, 5))
sns.barplot(x=importances, y=importances.index, palette="viridis")
plt.title("Feature Importances (Local Model)")
plt.xlabel("Importance Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### From Sagemaker Training
#
# <div align="center">
#   <img src="cw_logs.png" alt="CloudWatch output" style="width:80%;">
# </div>

# %% [markdown]
# ## Cleanup

# %% [markdown]
# Now that you've successfully trained and evaluated a model in the cloud, you’ve completed your first end-to-end managed ML workflow using SageMaker.
#
# ---
#
# ### Cleanup (Don’t Leave the Lights On)
#
# To avoid unnecessary AWS charges, we’ll delete all the resources we created:
#
# - **CloudFormation Stack**:
#   This will automatically delete:
#   - The SageMaker Studio domain
#   - The execution role
#   - The S3 bucket
#   You can do this programmatically using `boto3` (recommended), or…
#   *if you absolutely must*... use the [CloudFormation Console](https://console.aws.amazon.com/cloudformation) like a savage.
#
# - **CloudWatch Logs**:
#   These are optional to clean up, but can be removed from the [CloudWatch Console](https://console.aws.amazon.com/cloudwatch) if desired.

# %%
import boto3

cf = boto3.client("cloudformation")
stack_name = "caip02-cloud-ml-stack"

def delete_stack_and_wait(stack_name):
    print(f"🧨 Deleting stack: {stack_name}")
    
    # Initiate deletion
    cf.delete_stack(StackName=stack_name)

    # Wait until stack deletion is complete
    waiter = cf.get_waiter("stack_delete_complete")
    print("⏳ Waiting for stack to be fully deleted...")
    waiter.wait(StackName=stack_name)

    print(f"✅ Stack '{stack_name}' successfully deleted.")

# Call it
delete_stack_and_wait(stack_name)

# %% [markdown]
# ## Wrap-Up & Takeaways

# %% [markdown]
# In this notebook, you completed your first end-to-end cloud-based ML workflow using Amazon SageMaker. You:
#
# - Created a fully managed SageMaker Studio environment using CloudFormation
# - Cleaned and prepared the Titanic dataset
# - Wrote a training script (`train_model.py`) that runs in the cloud
# - Uploaded your data to S3
# - Launched a training job with the SKLearn Estimator
# - Viewed evaluation results (confusion matrix, classification report, feature importances) in CloudWatch
# - Compared cloud output with a local model to validate consistency
# - Cleaned up your resources programmatically using `boto3`
#
# ---
#
# This workflow reflects what real ML teams do in production:
#
# - Automate infra with Infrastructure-as-Code (IaC)
# - Package training logic into standalone scripts
# - Submit scalable, trackable jobs in the cloud
# - Monitor outputs in centralized logs
# - Maintain reproducibility between local dev and cloud runs
